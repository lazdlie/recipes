# %% [markdown]
# <a href="https://colab.research.google.com/github/lazdlie/recipes/blob/main/02-histograms-and-graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ROOT Basic Tools: histograms and graphs

# %% [markdown]
# # ROOT histograms
#
# [Histogram class documentation](https://root.cern.ch/doc/master/classTH1.html)
#
# ROOT has powerful histogram objects that, among other features, let you produce complex plots and perform fits of arbitrary functions.
#
# Below is an example histogram that can be obtained using one of our tutorials: [Higgs to Four Leptons](https://root.cern/doc/master/df106__HiggsToFourLeptons_8py.html).
#
# `TH1F` is a 1D histogram with Floating point y-axis, `TH2I` is a 2D histogram with Integer y-axis, etc.
#
# <center><img src="https://github.com/Aaravind96/software-carpentry/blob/PURSUE2026/images/examplehist_df106_HiggsToFourLeptons.png?raw=1"><center>

# %% [markdown]
# ### To have something to play with, let's quickly fill a histogram with 5000 normally distributed values.
#
# How to define a TH1D object?

# %%
pip install ROOT
# Out:
# Collecting ROOT
#   Downloading root-0.1a12-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ROOT) (2.0.2)
# Downloading root-0.1a12-cp312-cp312-manylinux_2_28_x86_64.whl (247.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.9/247.9 MB 5.4 MB/s eta 0:00:00
# Installing collected packages: ROOT
# Successfully installed ROOT-0.1a12

# %%
# Remember to import ROOT package!
import ROOT

# Try it!
# When you are not sure how to use a function, check its documentation by running ?ROOT.<function_name>
# ?ROOT.TH1D
# Out:
# /usr/local/lib/python3.12/dist-packages/ROOT/__init__.py:222: UserWarning:
# This distribution of ROOT is in alpha stage. Feedback is welcome and appreciated. Feel free to reach out to the user forum for questions and general feedback at https://root-forum.cern.ch or to submit an issue at https://github.com/root-project/root/issues. Do not rely on this distribution for production purposes.
#
#   warnings.warn(

# %%
# NEW CANVAS
h = ROOT.TH1D(name="h", title="My histo", nbinsx=100, xlow=-5, xup=5)

# Valies
h.FillRandom("gaus", ntimes=5000)

# %%
# Try it!
# To-do: import the ROOT module
import ROOT

# To-do: Create an empty histogram called "h1", with 50 bins, ranging from -1 to 1
h1 = ROOT.TH1D(name= "h1", title="First Histogram", nbinsx= 50, xlow=-1, xup=1)

# To-do: Fill the histogram with 1000 entries randomly sampled from a gaussian distribution
h1.FillRandom("gaus", ntimes=1000)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).

# %% [markdown]
# To check the full documentation you can always refer to https://root.cern/doc/master (and then switch to the documentation for your particular ROOT version with the drop-down menu at the top of the page).

# %% [markdown]
# ## Drawing a histogram

# %% [markdown]
# [Drawing options documentation](https://root.cern.ch/doc/master/classTHistPainter.html)
#
# The link above contains the documentation for the histogram drawing options.
#
# In a notebook, we want to use the `%jsroot on` magic and explicitly draw a `TCanvas`.

# %%
# %jsroot on
c1 = ROOT.TCanvas()
#h.SetLineColor(ROOT.kBlue)
#h.SetFillColor(ROOT.kBlue)
#h.GetXaxis().SetTitle("value")
#h.GetYaxis().SetTitle("count")
#h.SetTitle("My histo with latex: p_{t}, #eta, #phi")
h.Draw() # draw the histogram on the canvas
h1.Draw("SAMES")
c1.Draw() # draw the canvas on the screen
# Out:
# <div id="root_plot_1780326154283" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780326154283() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(140967,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780326154283', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780326154283();
# </script>

# %%
# %jsroot on

# Try it!
# To-do: Create a canvas
c1 = ROOT.TH1D(name="h1", title="My histo", nbinsx=100, xlow=-5, xup=5)

# To-do: Draw
# i. draw the histogram on the canvas
h1.Draw()
# ii. draw the canvas on the screen
c1.Draw()

# %%
# Try it!
# Try formatting the plot
# Example: Change the histogram line color to red
h.SetLineColor(ROOT.kRed)

# To-do: Fill the histogram with blue with SetFillColor()
h.SetFillColor(ROOT.kBlue)

# To-do: Set the title of y-axis as "count"
h.GetXaxis().SetTitle("value")
h.GetYaxis().SetTitle("count")


# To-do: Set the title of the plot as "My histo with latex: p_{t}, #eta, #phi" with function SetTitle()
h.SetTitle("My histo with latex: p_{t}, #eta, #phi")

# %%
# Try it!
# Draw it again
# To-do: i. draw the histogram on the canvas
h.Draw()
# To-do: ii. draw the canvas on the screen
c.Draw()
# Out:
# <div id="root_plot_1780326545223" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780326545223() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(137042,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780326545223', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780326545223();
# </script>

# %% [markdown]
# # ROOT functions

# %% [markdown]
# The type that represents an arbitrary one-dimensional mathematical function in ROOT is [TF1](https://root.cern.ch/doc/master/classTF1.html).<br>
# Similarly, [TF2](https://root.cern.ch/doc/master/classTF2.html) and [TF3](https://root.cern.ch/doc/master/classTF3.html) represent 2-dimensional and 3-dimensional functions.
#
# As an example, let's define and plot a simple surface:

# %%
f2 = ROOT.TF2("f2", "sin(x*x - y*y)", xmin=-2, xmax=2, ymin=-2, ymax=2)

# %%
# Try it!
# Define a 1D function f3 = x*x, with x ranging from -1 to 1
f3 = ROOT.TF1("my h", "x*x", xmin=-1, xmax=1)
# Note we use TF1() function instead of TF2() for 1D functions

# %%
c = ROOT.TCanvas()
f2.Draw("surf1") # to get a surface instead of the default contour plot
c.Draw()
# Out:
# <div id="root_plot_1780327109937" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780327109937() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(133813,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780327109937', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780327109937();
# </script>

# %%
# Try it!
# Explore drawing options
# To-do: See what the plot would look like if we change the option from "surf1" to "surf"
c = ROOT.TCanvas()
f2.Draw("surf1")
c.Draw()
# Out:
# <div id="root_plot_1780327113973" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780327113973() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(133813,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780327113973', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780327113973();
# </script>

# %%
# Draw your f3 and verify that it looks as expected
c = ROOT.TCanvas()
f3.Draw()
c.Draw()
# Out:
# <div id="root_plot_1780327118360" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780327118360() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(133895,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780327118360', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780327118360();
# </script>

# %% [markdown]
# ## Fitting a histogram

# %% [markdown]
# Let's see how to perform simple histogram fits of arbitrary functions. We will need a `TF1` that represents the function we want to use for the fit.
#
# This time we define our `TF1` as a C++ function (note the usage of the `%%cpp` magic to define some C++ inline). Here we define a simple gaussian with scale and mean parameters (`par[0]` and `par[1]` respectively):

# %%
# %%cpp
#
# double gaussian(double *x, double *par) {
#     return par[0]*TMath::Exp(-TMath::Power(x[0] - par[1], 2.) / 2.)
#            / TMath::Sqrt(2 * TMath::Pi());
# }

# %%
# Try it!
# Read the code above and write out the mathematical formula it describes e.g. f(x) = ax+b

# What is/are the parameters to be fitted?

# %% [markdown]
# The function signature, that takes an array of coordinates and an array of parameters as inputs, is the generic signature of functions that can be used to construct a `TF1` object:

# %%
fitFunc = ROOT.TF1("fitFunc", ROOT.gaussian, xmin=-5, xmax=5, npar=2)

# %% [markdown]
# Now we fit our `h` histogram with `fitFunc`:

# %%
res = h.Fit(fitFunc, "S") # the "S" option makes the function return a fit result object
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      57.2302
# NDf                       =           67
# Edm                       =  1.34911e-09
# NCalls                    =           44
# p0                        =      494.933   +/-   7.03982
# p1                        =    0.0173689   +/-   0.0142894

# %% [markdown]
# Drawing the histogram now automatically also shows the fitted function:

# %%
c2 = ROOT.TCanvas()
h.Draw()
c2.Draw()
# Out:
# <div id="root_plot_1780328025082" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780328025082() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(139647,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780328025082', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780328025082();
# </script>

# %% [markdown]
# For the particular case of a gaussian fit, we could also have used the built-in `"gaus"` function, as we did when we called `FillRandom` (for the full list of supported expressions see [here](https://root.cern/doc/master/classTFormula.html)):

# %%
res = h.Fit("gaus", "S")
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      57.2152
# NDf                       =           66
# Edm                       =  9.31601e-06
# NCalls                    =           55
# Constant                  =      197.704   +/-   3.46748
# Mean                      =    0.0172556   +/-   0.014353
# Sigma                     =      0.99873   +/-   0.0103909    	 (limited)

# %%
c3 = ROOT.TCanvas()
h.Draw()
c3.Draw()
# Out:
# <div id="root_plot_1780328060786" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780328060786() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(140150,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780328060786', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780328060786();
# </script>

# %% [markdown]
# ## ROOT graphs
#
# [TGraph](https://root.cern/doc/master/classTGraph.html) is a type useful for scatter plots.
#
# Their drawing options are documented [here](https://root.cern/doc/master/classTGraphPainter.html).
#
# Like for histograms, the aspect of `TGraph`s can be greatly customized, they can be fitted with custom functions, etc.

# %%
g = ROOT.TGraph()

for x in range(-20, 21):
    y = -x*x
    g.AddPoint(x, y)

c4 = ROOT.TCanvas()

# Example code
# Type with me!

g.Draw()
c4.Draw()
# Out:
# <div id="root_plot_1780328450209" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780328450209() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(134885,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780328450209', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780328450209();
# </script>

# %% [markdown]
# The same graph can be displayed as a bar plot:

# %%
c5 = ROOT.TCanvas()
g.SetTitle("My graph")
g.SetFillColor(ROOT.kOrange + 1) # base colors can be tweaked by adding/subtracting values to them
g.Draw("AB1")
c5.Draw()
# Out:
# <div id="root_plot_1780328684997" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780328684997() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(135780,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780328684997', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780328684997();
# </script>

# %% [markdown]
# ### Plot example: histogram stack
#
# In HEP, we often plot stacked histograms, for example to show the
# contributions of different processes. This can be done with [THStack](https://root.cern.ch/doc/master/classTHStack.html).

# %%
# Activity: explain this code to your neighbor

f1 = ROOT.TF1("f1", "gaus", -4.0, 4.0)

histos = [ROOT.TH1D(f"h{i}", "x", 64, -4.0, 4.0) for i in range(3)]

hs = ROOT.THStack("hs","")
hs.SetTitle(";x;Events")

colors = [46, 30, 38]

for i in range(len(histos)):
    h = histos[i]
    f1.SetParameters(1.0, i - 1, 1.0)
    h.FillRandom("f1", 100000)
    h.SetFillColor(colors[i])
    hs.Add(h)

c6 = ROOT.TCanvas()
hs.Draw()
c6.Draw()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h1 (Potential memory leak).
# <div id="root_plot_1780328697536" style="width: 700px; height: 500px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780328697536() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(140750,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780328697536', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780328697536();
# </script>

# %%
# To-do: In the code above (colors = [46, 30, 38]), what color does each number correspond to?
# Hint: https://root.cern.ch/doc/master/classTColor.html

# %% [markdown]
# ### Plot example: efficiency curves
#
# Another common workflow is to draw efficiency curves with [TEfficiency](https://root.cern.ch/doc/master/classTEfficiency.html), which also gives uncertainties.

# %%
# Example code
# Type with me!
f_gaus = ROOT.TF1("f_gaus", "gaus")
f_gaus.SetParameters(1.0, 48.0, 20.0)

h_pass = ROOT.TH1D("h_pass", "My histogram", 50, 0, 100.0)

h_pass.FillRandom("f_gaus", 40000)
h_pass.SetLineColor(ROOT.kRed)

f_gaus.SetParameters(1.0, 50.0, 20.0)

h_total = ROOT.TH1D("h_total", "My histogram", 50, 0, 100.0)
h_total.FillRandom("f_gaus", 100000)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h_pass (Potential memory leak).

# %%
teff = ROOT.TEfficiency(h_pass,h_total)

c7 = ROOT.TCanvas("rf101_basics", "rf101_basics", 800, 400)
c7.Divide(2)
c7.cd(1)
h_total.Draw()
h_pass.Draw("SAME")
c7.cd(2)
teff.Draw()
c7.Draw()
# Out:
# <div id="root_plot_1780329110224" style="width: 800px; height: 400px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1780329110224() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(147884,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1780329110224', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1780329110224();
# </script>

# %%
# Try it!
try_pass = ROOT.TH1D("try_pass", "My histogram", 50, 0, 100.0)
try_total = ROOT.TH1D("try_total", "My histogram", 50, 0, 100.0)

# To-do: Set the parameters of f_gaus with a = 1, mean = 50, std = 20
f_gaus.SetParameters(1.0, 50.0, 20.0)

# To-do: Fill try_pass with 50000 entries
try_pass.FillRandom("f_gaus", 50000)

# To-do: Edit the code below to fill try_total with 100000 entries
h_total.FillRandom("f_gaus", 100000)

# To-do: Calculate the efficiency using TEfficiency()
teff_try = ROOT.TEfficiency(try_pass, try_total)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: try_pass (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: try_total (Potential memory leak).
# Info in <TROOT::TEfficiency::CheckEntries>: Histograms are not consistent: passed bin content > total bin content
# Error in <TROOT::TEfficiency::CheckConsistency>: passed TEfficiency objects do not have consistent bin contents
# Error in <TEfficiency::TEfficiency(const TH1&,const TH1&)>: histograms are not consistent -> results are useless
# Warning in <TEfficiency::TEfficiency(const TH1&,const TH1&)>: using two empty TH1D('h1','h1',10,0,10)
